# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import matplotlib
matplotlib.rcParams["figure.figsize"]=(20,10)
# %matplotlib inline

# %%
df1=pd.read_csv("Delhi_v2.csv")
df1.head()
# Out:
#    Unnamed: 0       price                                            Address  \
# 0           0   5600000.0                  Noida Extension, Noida, Delhi NCR
# 1           1   8800000.0                      Sector 79, Gurgaon, Delhi NCR
# 2           2  16500000.0                     Vaishali, Ghaziabad, Delhi NCR
# 3           3   3810000.0  Link Road, F Block, Sector 50, Noida, Uttar Pr...
# 4           4   6200000.0  Jaypee Pavilion Court Sector 128, Noida, Secto...
#
#      area   latitude  longitude  Bedrooms  Bathrooms  Balcony  \
# 0  1350.0  28.608850  77.460560       3.0        3.0      NaN
# 1  1490.0  28.374236  76.952416       3.0        3.0      NaN
# 2  2385.0  28.645769  77.385110       4.0        5.0      NaN
# 3  1050.0  28.566914  77.436434       2.0        2.0      3.0
# 4  1350.0  28.520732  77.356491       2.0        2.0      3.0
#
#                Status      neworold  parking Furnished_status  Lift  \
# 0  Under Construction  New Property      NaN              NaN   2.0
# 1       Ready to Move  New Property      NaN   Semi-Furnished   2.0
# 2       Ready to Move  New Property      1.0      Unfurnished   NaN
# 3                 NaN  New Property      1.0      Unfurnished   2.0
# 4       Ready to Move        Resale      1.0              NaN   3.0
#
#                     Landmarks type_of_building  \
# 0                         NaN             Flat
# 1                         NaN             Flat
# 2                         NaN             Flat
# 3  near Gaur Mulberry Mansion             Flat
# 4                         NaN             Flat
#
#                                                 desc   Price_sqft
# 0  \n\n\n                                Welcome ...  4148.148148
# 1  \n\n\n                                Mapsko M...  5906.040268
# 2  \n\n\n                                This pro...  6918.238994
# 3  \n\n\n                                AIG Roya...  3628.571429
# 4  \n\n\n                                The prop...  4592.592593

# %%
df1.Address.unique()
# Out:
# array(['Noida Extension, Noida, Delhi NCR',
#        'Sector 79, Gurgaon, Delhi NCR', 'Vaishali, Ghaziabad, Delhi NCR',
#        ...,
#        'Sector137 Noida Paramount Floraville, Sector 137, Noida, Delhi NCR',
#        'Greater Noida, Sector 2, Greater Noida, Delhi NCR',
#        'sandal apartment, Shalimar Garden Extension 1, Ghaziabad, Delhi NCR'],
#       dtype=object)

# %%
df1.groupby("area_type")['price'].agg('mean')
# Out:
# area_type
# Built-up  Area          104.285498
# Carpet  Area             89.502356
# Plot  Area              208.495486
# Super built-up  Area     92.971757
# Name: price, dtype: float64

# %%
df2=df1.drop(df1[["latitude","longitude","parking","Balcony","Lift","Landmarks","desc"]],axis=1)
df2.head()
# Out:
#    Unnamed: 0       price                                            Address  \
# 0           0   5600000.0                  Noida Extension, Noida, Delhi NCR
# 1           1   8800000.0                      Sector 79, Gurgaon, Delhi NCR
# 2           2  16500000.0                     Vaishali, Ghaziabad, Delhi NCR
# 3           3   3810000.0  Link Road, F Block, Sector 50, Noida, Uttar Pr...
# 4           4   6200000.0  Jaypee Pavilion Court Sector 128, Noida, Secto...
#
#      area  Bedrooms  Bathrooms              Status      neworold  \
# 0  1350.0       3.0        3.0  Under Construction  New Property
# 1  1490.0       3.0        3.0       Ready to Move  New Property
# 2  2385.0       4.0        5.0       Ready to Move  New Property
# 3  1050.0       2.0        2.0                 NaN  New Property
# 4  1350.0       2.0        2.0       Ready to Move        Resale
#
#   Furnished_status type_of_building   Price_sqft
# 0              NaN             Flat  4148.148148
# 1   Semi-Furnished             Flat  5906.040268
# 2      Unfurnished             Flat  6918.238994
# 3      Unfurnished             Flat  3628.571429
# 4              NaN             Flat  4592.592593

# %%
df2.isnull().sum()
# Out:
# Unnamed: 0             0
# price                  0
# Address                0
# area                   0
# Bedrooms               0
# Bathrooms              0
# Status               574
# neworold               0
# Furnished_status    3614
# type_of_building       0
# Price_sqft             0
# dtype: int64

# %%
df3=df2.dropna()
df3.head()
# Out:
#     Unnamed: 0       price                                            Address  \
# 1            1   8800000.0                      Sector 79, Gurgaon, Delhi NCR
# 2            2  16500000.0                     Vaishali, Ghaziabad, Delhi NCR
# 10          10   7300000.0    Sector 24 Rohini, New Delhi - Rohini, Delhi NCR
# 12          12  10500000.0  Sector 110A, Gurgaon, Chandan Vihar, Gurgaon, ...
# 15          15   9500000.0    Sector 24 Rohini, New Delhi - Rohini, Delhi NCR
#
#       area  Bedrooms  Bathrooms         Status      neworold Furnished_status  \
# 1   1490.0       3.0        3.0  Ready to Move  New Property   Semi-Furnished
# 2   2385.0       4.0        5.0  Ready to Move  New Property      Unfurnished
# 10   850.0       3.0        2.0  Ready to Move  New Property   Semi-Furnished
# 12  1615.0       3.0        3.0  Ready to Move        Resale      Unfurnished
# 15  1000.0       3.0        2.0  Ready to Move  New Property   Semi-Furnished
#
#     type_of_building   Price_sqft
# 1               Flat  5906.040268
# 2               Flat  6918.238994
# 10              Flat  8588.235294
# 12              Flat  6501.547988
# 15  Individual House  9500.000000

# %%
df3.isnull().sum()
# Out:
# Unnamed: 0          0
# price               0
# Address             0
# area                0
# Bedrooms            0
# Bathrooms           0
# Status              0
# neworold            0
# Furnished_status    0
# type_of_building    0
# Price_sqft          0
# dtype: int64

# %%
df3.shape
# Out:
# (3556, 11)

# %%
df3['Bedrooms'].unique()
# Out:
# array([ 3.,  4.,  2.,  6.,  5., 10.,  8.,  7.,  9.])

# %%
df3['Bedrooms'].unique()
# Out:
# array([ 3.,  5.,  2.,  4.,  6.,  7.,  8., 10.,  9.])

# %%
df3["BHK"]=df3["Bedrooms"]
df3.head()
# Out:
# C:\Users\NAMAN PATHAK\AppData\Local\Temp\ipykernel_17552\3664852840.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3["BHK"]=df3["Bedrooms"]
#     Unnamed: 0       price                                            Address  \
# 1            1   8800000.0                      Sector 79, Gurgaon, Delhi NCR
# 2            2  16500000.0                     Vaishali, Ghaziabad, Delhi NCR
# 10          10   7300000.0    Sector 24 Rohini, New Delhi - Rohini, Delhi NCR
# 12          12  10500000.0  Sector 110A, Gurgaon, Chandan Vihar, Gurgaon, ...
# 15          15   9500000.0    Sector 24 Rohini, New Delhi - Rohini, Delhi NCR
#
#       area  Bedrooms  Bathrooms         Status      neworold Furnished_status  \
# 1   1490.0       3.0        3.0  Ready to Move  New Property   Semi-Furnished
# 2   2385.0       4.0        5.0  Ready to Move  New Property      Unfurnished
# 10   850.0       3.0        2.0  Ready to Move  New Property   Semi-Furnished
# 12  1615.0       3.0        3.0  Ready to Move        Resale      Unfurnished
# 15  1000.0       3.0        2.0  Ready to Move  New Property   Semi-Furnished
#
#     type_of_building   Price_sqft  BHK
# 1               Flat  5906.040268  3.0
# 2               Flat  6918.238994  4.0
# 10              Flat  8588.235294  3.0
# 12              Flat  6501.547988  3.0
# 15  Individual House  9500.000000  3.0

# %%
df4=df3.drop(df3[['Bedrooms']],axis=1)
df4.head()
# Out:
#     Unnamed: 0       price                                            Address  \
# 1            1   8800000.0                      Sector 79, Gurgaon, Delhi NCR
# 2            2  16500000.0                     Vaishali, Ghaziabad, Delhi NCR
# 10          10   7300000.0    Sector 24 Rohini, New Delhi - Rohini, Delhi NCR
# 12          12  10500000.0  Sector 110A, Gurgaon, Chandan Vihar, Gurgaon, ...
# 15          15   9500000.0    Sector 24 Rohini, New Delhi - Rohini, Delhi NCR
#
#       area  Bathrooms         Status      neworold Furnished_status  \
# 1   1490.0        3.0  Ready to Move  New Property   Semi-Furnished
# 2   2385.0        5.0  Ready to Move  New Property      Unfurnished
# 10   850.0        2.0  Ready to Move  New Property   Semi-Furnished
# 12  1615.0        3.0  Ready to Move        Resale      Unfurnished
# 15  1000.0        2.0  Ready to Move  New Property   Semi-Furnished
#
#     type_of_building   Price_sqft  BHK
Sector 24 Rohini, New Delhi - Rohini, Delhi NCR
#
#       area  Bathrooms         Status      neworold Furnished_status  \
# 1   1490.0        3.0  Ready to Move  New Property   Semi-Furnished
# 2   2385.0        5.0  Ready to Move  New Property      Unfurnished
# 10   850.0        2.0  Ready to Move  New Property   Semi-Furnished
# 12  1615.0        3.0  Ready to Move        Resale      Unfurnished
# 15  1000.0        2.0  Ready to Move  New Property   Semi-Furnished
#
#     type_of_building   Price_sqft  BHK
# 1               Flat  5906.040268  3.0
# 2               Flat  6918.238994  4.0
# 10              Flat  8588.235294  3.0
# 12              Flat  6501.547988  3.0
# 15  Individual House  9500.000000  3.0

# %%
(df4[~df4["area"].apply(is_float)]).area.unique()
# Out:
# array([], dtype=float64)

# %%
df4["location"]=df4["Address"]
df4=df4.drop(df4[['Address']],axis=1)
df4.head()
# Out:
#     Unnamed: 0       price    area  Bathrooms         Status      neworold  \
# 1            1   8800000.0  1490.0        3.0  Ready to Move  New Property
# 2            2  16500000.0  2385.0        5.0  Ready to Move  New Property
# 10          10   7300000.0   850.0        2.0  Ready to Move  New Property
# 12          12  10500000.0  1615.0        3.0  Ready to Move        Resale
# 15          15   9500000.0  1000.0        2.0  Ready to Move  New Property
#
#    Furnished_status  type_of_building   Price_sqft  BHK  \
# 1    Semi-Furnished              Flat  5906.040268  3.0
# 2       Unfurnished              Flat  6918.238994  4.0
# 10   Semi-Furnished              Flat  8588.235294  3.0
# 12      Unfurnished              Flat  6501.547988  3.0
# 15   Semi-Furnished  Individual House  9500.000000  3.0
#
#                                              location
# 1                       Sector 79, Gurgaon, Delhi NCR
# 2                      Vaishali, Ghaziabad, Delhi NCR
# 10    Sector 24 Rohini, New Delhi - Rohini, Delhi NCR
# 12  Sector 110A, Gurgaon, Chandan Vihar, Gurgaon, ...
# 15    Sector 24 Rohini, New Delhi - Rohini, Delhi NCR

# %%
len(df4.location.unique())
# Out:
# 2183

# %%
df4.location=df4.location.apply(lambda x:x.strip())
location_count=df4.groupby('location')['location'].agg('count').sort_values(ascending=False)
location_count
# Out:
# location
# Indirapuram, Ghaziabad, Delhi NCR                                       71
# Raj Nagar Extension, Ghaziabad, Delhi NCR                               54
# Noida Extension, Greater Noida, Delhi NCR                               35
# Greater Noida West, Greater Noida, Delhi NCR                            29
# Sahibabad, Ghaziabad, Delhi NCR                                         24
#                                                                         ..
# Gaur Yamuna City 16th Park View, Taj Expressway, Noida, Delhi NCR        1
# Gaur City 2, Noida, Uttar Pradesh, Noida Extension, Noida, Delhi NCR     1
# Gaur City 2 12th Avenue, Noida Extension, Noida, Delhi NCR               1
# Gardenia Grace Noida Sec61, Sector 61, Noida, Delhi NCR                  1
# zeta -1, Zeta, Greater Noida, Delhi NCR                                  1
# Name: location, Length: 2183, dtype: int64

# %%
less_count_location=location_count[location_count<=10]
less_count_location
# Out:
# location
# Sector 37D, Gurgaon, Delhi NCR                                          10
# Vasundhara, Ghaziabad, Delhi NCR                                        10
# Bhopura, Ghaziabad, Delhi NCR                                           10
# Sector 1 Vasundhara, Ghaziabad, Delhi NCR                               10
# Zeta 1, Greater Noida, Delhi NCR                                        10
#                                                                         ..
# Gaur Yamuna City 16th Park View, Taj Expressway, Noida, Delhi NCR        1
# Gaur City 2, Noida, Uttar Pradesh, Noida Extension, Noida, Delhi NCR     1
# Gaur City 2 12th Avenue, Noida Extension, Noida, Delhi NCR               1
# Gardenia Grace Noida Sec61, Sector 61, Noida, Delhi NCR                  1
# zeta -1, Zeta, Greater Noida, Delhi NCR                                  1
# Name: location, Length: 2156, dtype: int64

# %%
df4.location=df4.location.apply(lambda x:'other'if x in less_count_location else x)
len(df4.location.unique())
# Out:
# 28

# %%
df4.groupby('location')['location'].agg('count').sort_values(ascending=False)
# Out:
# location
# other                                                3013
# Indirapuram, Ghaziabad, Delhi NCR                      71
# Raj Nagar Extension, Ghaziabad, Delhi NCR              54
# Noida Extension, Greater Noida, Delhi NCR              35
# Greater Noida West, Greater Noida, Delhi NCR           29
# Sahibabad, Ghaziabad, Delhi NCR                        24
# Crossings Republik, Ghaziabad, Delhi NCR               23
# NH 24, Ghaziabad, Delhi NCR                            20
# Noida Extension, Noida, Delhi NCR                      20
# Vaishali, Ghaziabad, Delhi NCR                         19
# Shalimar Garden Extension 1, Ghaziabad, Delhi NCR      19
# Palam Vihar, Gurgaon, Delhi NCR                        17
# Techzone 4, Greater Noida, Delhi NCR                   17
# Niti Khand-Indirapuram, Ghaziabad, Delhi NCR           16
# Kaushambi, Ghaziabad, Delhi NCR                        16
# Sector 5 Vaishali, Ghaziabad, Delhi NCR                15
# Dwarka Mor, New Delhi - West, Delhi NCR                15
# Lal Kuan, Ghaziabad, Delhi NCR                         14
# Sector 5 Rajendra Nagar, Ghaziabad, Delhi NCR          13
# Uttam Nagar, New Delhi - West, Delhi NCR               13
# Sector 4 Vaishali, Ghaziabad, Delhi NCR                12
# Sector 57, Gurgaon, Delhi NCR                          12
# Sector 92, Gurgaon, Delhi NCR                          12
# Shalimar Garden Extension 2, Ghaziabad, Delhi NCR      12
# Govindpuram, Ghaziabad, Delhi NCR                      12
# Shakti Khand 2, Ghaziabad, Delhi NCR                   11
# Uttam Nagar West, New Delhi - West, Delhi NCR          11
# Sector 16, Greater Noida, Delhi NCR                    11
# Name: location, dtype: int64

# %%
df4[:11]
# Out:
#     Unnamed: 0       price    area  Bathrooms         Status      neworold  \
# 1            1   8800000.0  1490.0        3.0  Ready to Move  New Property
# 2            2  16500000.0  2385.0        5.0  Ready to Move  New Property
# 10          10   7300000.0   850.0        2.0  Ready to Move  New Property
# 12          12  10500000.0  1615.0        3.0  Ready to Move        Resale
# 15          15   9500000.0  1000.0        2.0  Ready to Move  New Property
# 16          16  15000000.0  1450.0        3.0  Ready to Move  New Property
# 18          18   5100000.0  1087.0        2.0  Ready to Move        Resale
# 21          21   8700000.0  1600.0        2.0  Ready to Move        Resale
# 27          27  10000000.0  1836.0        2.0  Ready to Move        Resale
# 30          30   9000000.0  1481.0        2.0  Ready to Move        Resale
# 33          33   5310000.0  1100.0        2.0  Ready to Move        Resale
#
#    Furnished_status  type_of_building    Price_sqft  BHK  \
# 1    Semi-Furnished              Flat   5906.040268  3.0
# 2       Unfurnished              Flat   6918.238994  4.0
# 10   Semi-Furnished              Flat   8588.235294  3.0
# 12      Unfurnished              Flat   6501.547988  3.0
# 15   Semi-Furnished  Individual House   9500.000000  3.0
# 16   Semi-Furnished  Individual House  10344.827586  4.0
# 18   Semi-Furnished              Flat   4691.812328  2.0
# 21      Unfurnished              Flat   5437.500000  3.0
# 27   Semi-Furnished  Individual House   5446.623094  3.0
# 30      Unfurnished              Flat   6076.975017  2.0
# 33        Furnished              Flat   4827.272727  3.0
#
#                                 location
# 1                                  other
# 2         Vaishali, Ghaziabad, Delhi NCR
# 10                                 other
# 12                                 other
# 15                                 other
# 16                                 other
# 18                                 other
# 21                                 other
# 27                                 other
# 30                                 other
# 33  Shakti Khand 2, Ghaziabad, Delhi NCR

# %%
df4.shape
# Out:
# (3556, 11)

# %%
len(df4.Furnished_status.unique())
# Out:
# 3

# %%
df4.head()
# Out:
#     Unnamed: 0       price    area  Bathrooms         Status      neworold  \
# 1            1   8800000.0  1490.0        3.0  Ready to Move  New Property
# 2            2  16500000.0  2385.0        5.0  Ready to Move  New Property
# 10          10   7300000.0   850.0        2.0  Ready to Move  New Property
# 12          12  10500000.0  1615.0        3.0  Ready to Move        Resale
# 15          15   9500000.0  1000.0        2.0  Ready to Move  New Property
#
#    Furnished_status  type_of_building   Price_sqft  BHK  \
# 1    Semi-Furnished              Flat  5906.040268  3.0
# 2       Unfurnished              Flat  6918.238994  4.0
# 10   Semi-Furnished              Flat  8588.235294  3.0
# 12      Unfurnished              Flat  6501.547988  3.0
# 15   Semi-Furnished  Individual House  9500.000000  3.0
#
#                           location
# 1                            other
# 2   Vaishali, Ghaziabad, Delhi NCR
# 10                           other
# 12                           other
# 15                           other

# %%
df5=df4[~(df4.type_of_building=="Individual House")]
df5.shape
# Out:
# (2850, 11)

# %%
len(df5.type_of_building.unique())
# Out:
# 1

# %%
df6=df5[df5.Bathrooms<df5.BHK+2]
df6.shape
# Out:
# (2837, 11)

# %%
def remove_price_outliers(df):
    df_output=pd.DataFrame()
    for key,location_info in df.groupby('location'):
        mean=np.mean(location_info['Price_sqft'])
        std=np.std(location_info['Price_sqft'])
        reduce_df=location_info[(location_info['Price_sqft']>(mean-std)) & (location_info['Price_sqft']<=(mean+std))]
        df_output=pd.concat([df_output,reduce_df],ignore_index=True)
    return df_output

df7=remove_price_outliers(df6)
df7.shape
# Out:
# (2260, 11)

# %%
def remove_location_price_outliers(df):
    exclude_idx=np.array([])
    for location,location_info in df.groupby('location'):
        bhk_info={}
        for bhk,bhk_stat in location_info.groupby('BHK'):
             bhk_info[bhk]={
            'mean':np.mean(bhk_stat['Price_sqft']),
            'std':np.std(bhk_stat['Price_sqft']),
            'count':bhk_stat.shape[0]
        }
        for bhk,bhk_stat in location_info.groupby('BHK'):
            prev_info=bhk_info.get(bhk-1)
            if prev_info and prev_info['count']>5:
                exclude_idx=np.append(exclude_idx,bhk_stat[bhk_stat['Price_sqft']<(prev_info['mean'])].index.values)
    return df.drop(exclude_idx,axis='index')     
        
df8=remove_location_price_outliers(df7)
df8.shape
# Out:
# (1768, 11)

# %%
df8.head()
# Out:
#    Unnamed: 0      price    area  Bathrooms         Status neworold  \
# 0        2006  4000000.0  1150.0        2.0  Ready to Move   Resale
# 1        2035  4670000.0  1320.0        2.0  Ready to Move   Resale
# 2        2132  4600000.0  1400.0        2.0  Ready to Move   Resale
# 3        2669  3450000.0  1075.0        2.0  Ready to Move   Resale
# 4        3794  4300000.0  1200.0        2.0  Ready to Move   Resale
#
#   Furnished_status type_of_building   Price_sqft  BHK  \
# 0      Unfurnished             Flat  3478.260870  2.0
# 1   Semi-Furnished             Flat  3537.878788  3.0
# 2        Furnished             Flat  3285.714286  2.0
# 3   Semi-Furnished             Flat  3209.302326  2.0
# 4   Semi-Furnished             Flat  3583.333333  2.0
#
#                                    location
# 0  Crossings Republik, Ghaziabad, Delhi NCR
# 1  Crossings Republik, Ghaziabad, Delhi NCR
# 2  Crossings Republik, Ghaziabad, Delhi NCR
# 3  Crossings Republik, Ghaziabad, Delhi NCR
# 4  Crossings Republik, Ghaziabad, Delhi NCR

# %%
df9=df8.drop(['Price_sqft',"type_of_building","Status","neworold","Furnished_status"],axis=1)
df9.shape
# Out:
# (1768, 6)

# %%
df9=df9.drop(["Unnamed: 0"],axis=1)

# %%
df9.head()
# Out:
#        price    area  Bathrooms  BHK                                  location
# 0  4000000.0  1150.0        2.0  2.0  Crossings Republik, Ghaziabad, Delhi NCR
# 1  4670000.0  1320.0        2.0  3.0  Crossings Republik, Ghaziabad, Delhi NCR
# 2  4600000.0  1400.0        2.0  2.0  Crossings Republik, Ghaziabad, Delhi NCR
# 3  3450000.0  1075.0        2.0  2.0  Crossings Republik, Ghaziabad, Delhi NCR
# 4  4300000.0  1200.0        2.0  2.0  Crossings Republik, Ghaziabad, Delhi NCR

# %%
dummies=pd.get_dummies(df9.location);
df10=pd.concat([df9,dummies.drop('other',axis=1)],axis='columns')
df10.head()
# Out:
#        price    area  Bathrooms  BHK  \
# 0  4000000.0  1150.0        2.0  2.0
# 1  4670000.0  1320.0        2.0  3.0
# 2  4600000.0  1400.0        2.0  2.0
# 3  3450000.0  1075.0        2.0  2.0
# 4  4300000.0  1200.0        2.0  2.0
#
#                                    location  \
# 0  Crossings Republik, Ghaziabad, Delhi NCR
# 1  Crossings Republik, Ghaziabad, Delhi NCR
# 2  Crossings Republik, Ghaziabad, Delhi NCR
# 3  Crossings Republik, Ghaziabad, Delhi NCR
# 4  Crossings Republik, Ghaziabad, Delhi NCR
#
#    Crossings Republik, Ghaziabad, Delhi NCR  \
# 0                                      True
# 1                                      True
# 2                                      True
# 3                                      True
# 4                                      True
#
#    Dwarka Mor, New Delhi - West, Delhi NCR  Govindpuram, Ghaziabad, Delhi NCR  \
# 0                                    False                              False
# 1                                    False                              False
# 2                                    False                              False
# 3                                    False                              False
# 4                                    False                              False
#
#    Greater Noida West, Greater Noida, Delhi NCR  \
# 0                                         False
# 1                                         False
# 2                                         False
# 3                                         False
# 4                                         False
#
#    Indirapuram, Ghaziabad, Delhi NCR  ...  \
# 0                              False  ...
# 1                              False  ...
# 2                              False  ...
# 3                              False  ...
# 4                              False  ...
#
#    Sector 5 Vaishali, Ghaziabad, Delhi NCR  Sector 57, Gurgaon, Delhi NCR  \
# 0                                    False                          False
# 1                                    False                          False
# 2                                    False                          False
# 3                                    False                          False
# 4                                    False                          False
#
#    Sector 92, Gurgaon, Delhi NCR  Shakti Khand 2, Ghaziabad, Delhi NCR  \
# 0                          False                                 False
# 1                          False                                 False
# 2                          False                                 False
# 3                          False                                 False
# 4                          False                                 False
#
#    Shalimar Garden Extension 1, Ghaziabad, Delhi NCR  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Shalimar Garden Extension 2, Ghaziabad, Delhi NCR  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Techzone 4, Greater Noida, Delhi NCR  \
# 0                                 False
# 1                                 False
# 2                                 False
# 3                                 False
# 4                                 False
#
#    Uttam Nagar West, New Delhi - West, Delhi NCR  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
#
#    Uttam Nagar, New Delhi - West, Delhi NCR  Vaishali, Ghaziabad, Delhi NCR
# 0                                     False                           False
# 1                                     False                           False
# 2                                     False                           False
# 3                                     False                           False
# 4                                     False                           False
#
# [5 rows x 32 columns]

# %%
df11=df10.drop('location',axis=1)
df11.head()
# Out:
#        price    area  Bathrooms  BHK  \
# 0  4000000.0  1150.0        2.0  2.0
# 1  4670000.0  1320.0        2.0  3.0
# 2  4600000.0  1400.0        2.0  2.0
# 3  3450000.0  1075.0        2.0  2.0
# 4  4300000.0  1200.0        2.0  2.0
#
#    Crossings Republik, Ghaziabad, Delhi NCR  \
# 0                                      True
# 1                                      True
# 2                                      True
# 3                                      True
# 4                                      True
#
#    Dwarka Mor, New Delhi - West, Delhi NCR  Govindpuram, Ghaziabad, Delhi NCR  \
# 0                                    False                              False
# 1                                    False                              False
# 2                                    False                              False
# 3                                    False                              False
# 4                                    False                              False
#
#    Greater Noida West, Greater Noida, Delhi NCR  \
# 0                                         False
# 1                                         False
# 2                                         False
# 3                                         False
# 4                                         False
#
#    Indirapuram, Ghaziabad, Delhi NCR  Kaushambi, Ghaziabad, Delhi NCR  ...  \
# 0                              False                            False  ...
# 1                              False                            False  ...
# 2                              False                            False  ...
# 3                              False                            False  ...
# 4                              False                            False  ...
#
#    Sector 5 Vaishali, Ghaziabad, Delhi NCR  Sector 57, Gurgaon, Delhi NCR  \
# 0                                    False                          False
# 1                                    False                          False
# 2                                    False                          False
# 3                                    False                          False
# 4                                    False                          False
#
#    Sector 92, Gurgaon, Delhi NCR  Shakti Khand 2, Ghaziabad, Delhi NCR  \
# 0                          False                                 False
# 1                          False                                 False
# 2                          False                                 False
# 3                          False                                 False
# 4                          False                                 False
#
#    Shalimar Garden Extension 1, Ghaziabad, Delhi NCR  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Shalimar Garden Extension 2, Ghaziabad, Delhi NCR  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Techzone 4, Greater Noida, Delhi NCR  \
# 0                                 False
# 1                                 False
# 2                                 False
# 3                                 False
# 4                                 False
#
#    Uttam Nagar West, New Delhi - West, Delhi NCR  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
#
#    Uttam Nagar, New Delhi - West, Delhi NCR  Vaishali, Ghaziabad, Delhi NCR
# 0                                     False                           False
# 1                                     False                           False
# 2                                     False                           False
# 3                                     False                           False
# 4                                     False                           False
#
# [5 rows x 31 columns]

# %%
df11.shape
# Out:
# (1768, 31)

# %%
X=df11.drop(['price'],axis=1)
X.head()
# Out:
#      area  Bathrooms  BHK  Crossings Republik, Ghaziabad, Delhi NCR  \
# 0  1150.0        2.0  2.0                                      True
# 1  1320.0        2.0  3.0                                      True
# 2  1400.0        2.0  2.0                                      True
# 3  1075.0        2.0  2.0                                      True
# 4  1200.0        2.0  2.0                                      True
#
#    Dwarka Mor, New Delhi - West, Delhi NCR  Govindpuram, Ghaziabad, Delhi NCR  \
# 0                                    False                              False
# 1                                    False                              False
# 2                                    False                              False
# 3                                    False                              False
# 4                                    False                              False
#
#    Greater Noida West, Greater Noida, Delhi NCR  \
# 0                                         False
# 1                                         False
# 2                                         False
# 3                                         False
# 4                                         False
#
#    Indirapuram, Ghaziabad, Delhi NCR  Kaushambi, Ghaziabad, Delhi NCR  \
# 0                              False                            False
# 1                              False                            False
# 2                              False                            False
# 3                              False                            False
# 4                              False                            False
#
#    Lal Kuan, Ghaziabad, Delhi NCR  ...  \
# 0                           False  ...
# 1                           False  ...
# 2                           False  ...
# 3                           False  ...
# 4                           False  ...
#
#    Sector 5 Vaishali, Ghaziabad, Delhi NCR  Sector 57, Gurgaon, Delhi NCR  \
# 0                                    False                          False
# 1                                    False                          False
# 2                                    False                          False
# 3                                    False                          False
# 4                                    False                          False
#
#    Sector 92, Gurgaon, Delhi NCR  Shakti Khand 2, Ghaziabad, Delhi NCR  \
# 0                          False                                 False
# 1                          False                                 False
# 2                          False                                 False
# 3                          False                                 False
# 4                          False                                 False
#
#    Shalimar Garden Extension 1, Ghaziabad, Delhi NCR  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Shalimar Garden Extension 2, Ghaziabad, Delhi NCR  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Techzone 4, Greater Noida, Delhi NCR  \
# 0                                 False
# 1                                 False
# 2                                 False
# 3                                 False
# 4                                 False
#
#    Uttam Nagar West, New Delhi - West, Delhi NCR  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
#
#    Uttam Nagar, New Delhi - West, Delhi NCR  Vaishali, Ghaziabad, Delhi NCR
# 0                                     False                           False
# 1                                     False                           False
# 2                                     False                           False
# 3                                     False                           False
# 4                                     False                           False
#
# [5 rows x 30 columns]

# %%
y=df11.price
y.head()
# Out:
# 0    4000000.0
# 1    4670000.0
# 2    4600000.0
# 3    3450000.0
# 4    4300000.0
# Name: price, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=10)
len(X_train)
# Out:
# 1414

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model.score(X_test,y_test)
# Out:
# 0.9525224701673567

# %%
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score
cv=ShuffleSplit(n_splits=5,test_size=0.2,random_state=0)
cross_val_score(LinearRegression(),X,y,cv=cv)
# Out:
# array([0.91330973, 0.9237233 , 0.90710055, 0.92783054, 0.93791278])

# %%
from sklearn.linear_model import LinearRegression, Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import GridSearchCV, ShuffleSplit
import pandas as pd

def find_best_model(X, y):
    params_info = {
        'linear_regression': {
            'model': LinearRegression(),
            'params': {
                #'normalize': [True, False]
            }
        },
        'lasso_regression': {
            'model': Lasso(),
            'params': {
                'alpha': [1, 2],
                'selection': ['random', 'cyclic']
            }
        },
        'decision_tree': {
            'model': DecisionTreeRegressor(),
            'params': {
                'criterion': ['mse', 'friedman_mse'],
                'splitter': ['best', 'random']
            }
        }
    }
    cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=0)
    score = []
    for model_name, config in params_info.items():
        gs = GridSearchCV(config['model'], config['params'], cv=cv, return_train_score=False)
        gs.fit(X, y)
        score.append({
            'model': model_name,
            'best_score': gs.best_score_,
            'best_params': gs.best_params_
        })

    return pd.DataFrame(score, columns=['model', 'best_score', 'best_params'])
    
find_best_model(X,y)
# Out:
# C:\Users\NAMAN PATHAK\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py:547: FitFailedWarning:
# 10 fits failed out of a total of 20.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 10 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\NAMAN PATHAK\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py", line 895, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\NAMAN PATHAK\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 1467, in wrapper
#     estimator._validate_params()
#   File "C:\Users\NAMAN PATHAK\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\NAMAN PATHAK\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of DecisionTreeRegressor must be a str among {'friedman_mse', 'squared_error', 'absolute_error', 'poisson'}. Got 'mse' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\NAMAN PATHAK\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_search.py:1051: UserWarning: One or more of the test scores are non-finite: [       nan        nan 0.90412915 0.89881656]
#   warnings.warn(
#                model  best_score  \
# 0  linear_regression    0.921975
# 1   lasso_regression    0.921976
# 2      decision_tree    0.904129
#
#                                          best_params
# 0                                                 {}
# 1                {'alpha': 2, 'selection': 'cyclic'}
# 2  {'criterion': 'friedman_mse', 'splitter': 'best'}

# %%
X.head()
# Out:
#      area  Bathrooms  BHK  Crossings Republik, Ghaziabad, Delhi NCR  \
# 0  1150.0        2.0  2.0                                      True
# 1  1320.0        2.0  3.0                                      True
# 2  1400.0        2.0  2.0                                      True
# 3  1075.0        2.0  2.0                                      True
# 4  1200.0        2.0  2.0                                      True
#
#    Dwarka Mor, New Delhi - West, Delhi NCR  Govindpuram, Ghaziabad, Delhi NCR  \
# 0                                    False                              False
# 1                                    False                              False
# 2                                    False                              False
# 3                                    False                              False
# 4                                    False                              False
#
#    Greater Noida West, Greater Noida, Delhi NCR  \
# 0                                         False
# 1                                         False
# 2                                         False
# 3                                         False
# 4                                         False
#
#    Indirapuram, Ghaziabad, Delhi NCR  Kaushambi, Ghaziabad, Delhi NCR  \
# 0                              False                            False
# 1                              False                            False
# 2                              False                            False
# 3                              False                            False
# 4                              False                            False
#
#    Lal Kuan, Ghaziabad, Delhi NCR  ...  \
# 0                           False  ...
# 1                           False  ...
# 2                           False  ...
# 3                           False  ...
# 4                           False  ...
#
#    Sector 5 Vaishali, Ghaziabad, Delhi NCR  Sector 57, Gurgaon, Delhi NCR  \
# 0                                    False                          False
# 1                                    False                          False
# 2                                    False                          False
# 3                                    False                          False
# 4                                    False                          False
#
#    Sector 92, Gurgaon, Delhi NCR  Shakti Khand 2, Ghaziabad, Delhi NCR  \
# 0                          False                                 False
# 1                          False                                 False
# 2                          False                                 False
# 3                          False                                 False
# 4                          False                                 False
#
#    Shalimar Garden Extension 1, Ghaziabad, Delhi NCR  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Shalimar Garden Extension 2, Ghaziabad, Delhi NCR  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Techzone 4, Greater Noida, Delhi NCR  \
# 0                                 False
# 1                                 False
# 2                                 False
# 3                                 False
# 4                                 False
#
#    Uttam Nagar West, New Delhi - West, Delhi NCR  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
#
#    Uttam Nagar, New Delhi - West, Delhi NCR  Vaishali, Ghaziabad, Delhi NCR
# 0                                     False                           False
# 1                                     False                           False
# 2                                     False                           False
# 3                                     False                           False
# 4                                     False                           False
#
# [5 rows x 30 columns]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=10)
model=LinearRegression()
model.fit(X_train,y_train)

def predict_price(location,sqft,bath,bhk):
    loc_idx=np.where(X.columns==location)[0][0]
    
    x=np.zeros(len(X.columns))
    x[0]=sqft
    x[1]=bath
    x[2]=bhk
    if loc_idx>=0:
        x[loc_idx]=1
    return model.predict([x])[0]

# %%
predict_price('Crossings Republik, Ghaziabad, Delhi NCR',1500,2,2)
# Out:
# C:\Users\NAMAN PATHAK\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 5570771.727514485

# %%
y.head()
# Out:
# 0    4000000.0
# 1    4670000.0
# 2    4600000.0
# 3    3450000.0
# 4    4300000.0
# Name: price, dtype: float64

# %%
import pickle
with open('delhi_price_prediction_model.pickle','wb') as f:
    pickle.dump(model,f)

# %%
import json
columns_info={
    'df_columns':[col.lower() for col in X.columns]
}
with open('delhi_columns.json','w') as f:
    f.write(json.dumps(columns_info))
